# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
order_reviews = pd.read_csv("../../Datasets_Olist/olist_order_reviews_dataset.csv")
order_reviews.head(5)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
order_reviews.shape
# Out:
# (99224, 7)

# %%
order_reviews['review_score'].unique()
# Out:
# array([4, 5, 1, 3, 2])

# %%
order_reviews['review_id'].nunique()
# Out:
# 98410

# %%
reviews_per_score = order_reviews["review_score"].value_counts()

plt.figure(figsize= (6, 6))
plt.pie(reviews_per_score, labels = reviews_per_score.index, autopct='%1.1f%%')
plt.title("Number of review per score")

plt.show()
